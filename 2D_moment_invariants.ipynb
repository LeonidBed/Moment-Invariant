# %%
# import numpy as np
import sympy
#from sympy import binomial, Symbol, expand, simplify, Sum
from sympy.abc import j,k
from sympy import *
from IPython.display import display, Latex
init_printing()
x,y=sympy.symbols('x,y')
a=IndexedBase('a')
eta=IndexedBase('eta')


def Kpol(n,b,x):#Многочлени Кравчука
    return expand(simplify(sum([(-1)**i*binomial(x,i)*binomial(b-x,n-i) for  i in range(n+1)])))
def Kpol1(n,a,x):#Многочлени Кравчука
    return simplify(Sum((-1)**j*binomial(x,j)*binomial(a-x,n-j), (j,0,n) ).doit())
def E(d,l):#власні вектори
    return Sum(I**k*floor(Kpol1(k,d,(d-l)/2))*eta[d-k,k], (k,0,d+1)).doit()

def Re_Im(z):# exctract of real and imaginary parts
    return collect(z.subs(I,y),y).subs(y,I)


'''                            2D geometric moments             '''

def I0(d):# Invariants of degree 1
    return [E(2*i,0) for i in range(1,floor(d/2)+1)]

def I11(n):# Invariants of degree 2 
    return [expand(E(n,n-2*i)*E(n,-n+2*i)) for i in range(floor((n+1)/2))]

def I1(d):# List  
        S=[]
        for i in range(2,d+1):
            S=S+I11(i)
        return S
def I22(n,p,q):#invariants of degree p+q
    Epq=E(p,-q)
    return [Re_Im(expand((E(n,n-2*i)**q*Epq**n))) for i in range(floor((n+1)/2)) if [n,n-2*i] !=[p,q]] or n !=2
def I222(n,d):#invariants of degree p+q
    Epq=E(3,-1)
    A=[Re_Im(expand((E(n,n-2*i)*Epq**(n-2*i)))) for i in range(floor((n+1)/2)) if [n,n-2*i] !=[3,1]]
    if n==2 and d==2:
        A=[]
    return A

def I2(d):# List  
        S=[]
        for i in range(2,d+1):
            S=S+I222(i,d)
        return S
def Minimal_generating_set_2D(d):# Minimal generating set of invariants upp to order d
    return I0(d)+I1(d)+I2(d)

# %%
Minimal_generating_set_2D(3)
# Out:
# ⎡                                2                                      2
# ⎣eta[0, 2] + eta[2, 0], eta[0, 2]  - 2⋅eta[0, 2]⋅eta[2, 0] + 4⋅eta[1, 1]  + et
#
#        2           2                                      2
# a[2, 0] , eta[0, 3]  - 6⋅eta[0, 3]⋅eta[2, 1] + 9⋅eta[1, 2]  - 6⋅eta[1, 2]⋅eta[
#
#                    2            2           2
# 3, 0] + 9⋅eta[2, 1]  + eta[3, 0] , eta[0, 3]  + 2⋅eta[0, 3]⋅eta[2, 1] + eta[1,
#
#    2                                    2            2    ⎛
#  2]  + 2⋅eta[1, 2]⋅eta[3, 0] + eta[2, 1]  + eta[3, 0] , ⅈ⋅⎝2⋅eta[0, 2]⋅eta[0,
#
#
# 3]⋅eta[1, 2] + 2⋅eta[0, 2]⋅eta[0, 3]⋅eta[3, 0] + 2⋅eta[0, 2]⋅eta[1, 2]⋅eta[2,
#
#                                                   2
# 1] + 2⋅eta[0, 2]⋅eta[2, 1]⋅eta[3, 0] - 2⋅eta[0, 3] ⋅eta[1, 1] - 4⋅eta[0, 3]⋅et
#
#
# a[1, 1]⋅eta[2, 1] - 2⋅eta[0, 3]⋅eta[1, 2]⋅eta[2, 0] - 2⋅eta[0, 3]⋅eta[2, 0]⋅et
#
#                                2
# a[3, 0] + 2⋅eta[1, 1]⋅eta[1, 2]  + 4⋅eta[1, 1]⋅eta[1, 2]⋅eta[3, 0] - 2⋅eta[1,
#
#             2                        2
# 1]⋅eta[2, 1]  + 2⋅eta[1, 1]⋅eta[3, 0]  - 2⋅eta[1, 2]⋅eta[2, 0]⋅eta[2, 1] - 2⋅e
#
#                             ⎞                      2
# ta[2, 0]⋅eta[2, 1]⋅eta[3, 0]⎠ + eta[0, 2]⋅eta[0, 3]  + 2⋅eta[0, 2]⋅eta[0, 3]⋅e
#
#                               2
# ta[2, 1] - eta[0, 2]⋅eta[1, 2]  - 2⋅eta[0, 2]⋅eta[1, 2]⋅eta[3, 0] + eta[0, 2]⋅
#
#          2                      2            2
# eta[2, 1]  - eta[0, 2]⋅eta[3, 0]  - eta[0, 3] ⋅eta[2, 0] + 4⋅eta[0, 3]⋅eta[1,
#
#
# 1]⋅eta[1, 2] + 4⋅eta[0, 3]⋅eta[1, 1]⋅eta[3, 0] - 2⋅eta[0, 3]⋅eta[2, 0]⋅eta[2,
#
#
# 1] + 4⋅eta[1, 1]⋅eta[1, 2]⋅eta[2, 1] + 4⋅eta[1, 1]⋅eta[2, 1]⋅eta[3, 0] + eta[1
#
#     2                                                                  2
# , 2] ⋅eta[2, 0] + 2⋅eta[1, 2]⋅eta[2, 0]⋅eta[3, 0] - eta[2, 0]⋅eta[2, 1]  + eta
#
#                 2    ⎛           3                         2
# [2, 0]⋅eta[3, 0] , ⅈ⋅⎝4⋅eta[0, 3] ⋅eta[3, 0] - 12⋅eta[0, 3] ⋅eta[1, 2]⋅eta[2,
#
#                           3                         2
# 1] + 8⋅eta[0, 3]⋅eta[1, 2]  + 12⋅eta[0, 3]⋅eta[1, 2] ⋅eta[3, 0] - 24⋅eta[0, 3]
#
#                     2                         2
# ⋅eta[1, 2]⋅eta[2, 1]  - 12⋅eta[0, 3]⋅eta[2, 1] ⋅eta[3, 0] - 4⋅eta[0, 3]⋅eta[3,
#
#    3               3                         2
#  0]  + 12⋅eta[1, 2] ⋅eta[2, 1] + 24⋅eta[1, 2] ⋅eta[2, 1]⋅eta[3, 0] - 12⋅eta[1,
#
#              3                                   2              3          ⎞
#  2]⋅eta[2, 1]  + 12⋅eta[1, 2]⋅eta[2, 1]⋅eta[3, 0]  - 8⋅eta[2, 1] ⋅eta[3, 0]⎠ +
#
#           4              2          2              2          2              2
#  eta[0, 3]  + 6⋅eta[0, 3] ⋅eta[1, 2]  - 6⋅eta[0, 3] ⋅eta[2, 1]  - 6⋅eta[0, 3]
#
#           2                         2
# ⋅eta[3, 0]  + 24⋅eta[0, 3]⋅eta[1, 2] ⋅eta[2, 1] + 24⋅eta[0, 3]⋅eta[1, 2]⋅eta[2
#
#                                       3              4              3
# , 1]⋅eta[3, 0] - 8⋅eta[0, 3]⋅eta[2, 1]  - 3⋅eta[1, 2]  - 8⋅eta[1, 2] ⋅eta[3, 0
#
#                 2          2              2          2
# ] + 18⋅eta[1, 2] ⋅eta[2, 1]  - 6⋅eta[1, 2] ⋅eta[3, 0]  + 24⋅eta[1, 2]⋅eta[2, 1
#
#  2                        4              2          2            4⎤
# ] ⋅eta[3, 0] - 3⋅eta[2, 1]  + 6⋅eta[2, 1] ⋅eta[3, 0]  + eta[3, 0] ⎦
